# %%
import requests
import string
from bs4 import BeautifulSoup
page = requests.get("https://fr.wikipedia.org/wiki/Python_(langage)")
soup = BeautifulSoup(page.content, 'html.parser')
title = soup.title.string
for script in soup(["script", "style"]):
    script.decompose()
strips = list(soup.stripped_strings)
soup.find_all("a") 
for tag in soup.find_all("a"): 
    print(tag["href"])
# Out:
# #bodyContent
# /wiki/Wikip%C3%A9dia:Accueil_principal
# /wiki/Portail:Accueil
# /wiki/Sp%C3%A9cial:Page_au_hasard
# /wiki/Wikip%C3%A9dia:Contact
# /wiki/Aide:D%C3%A9buter
# /wiki/Aide:Accueil
# /wiki/Wikip%C3%A9dia:Accueil_de_la_communaut%C3%A9
# /wiki/Sp%C3%A9cial:Modifications_r%C3%A9centes
# //donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_fr.wikipedia.org&uselang=fr
# #p-lang-btn
# /wiki/Wikip%C3%A9dia:Accueil_principal
# /wiki/Sp%C3%A9cial:Recherche
# /w/index.php?title=Sp%C3%A9cial:Cr%C3%A9er_un_compte&returnto=Python+%28langage%29
# /w/index.php?title=Sp%C3%A9cial:Connexion&returnto=Python+%28langage%29
# /w/index.php?title=Sp%C3%A9cial:Cr%C3%A9er_un_compte&returnto=Python+%28langage%29
# /w/index.php?title=Sp%C3%A9cial:Connexion&returnto=Python+%28langage%29
# /wiki/Aide:Introduction
# /wiki/Sp%C3%A9cial:Mes_contributions
# /wiki/Sp%C3%A9cial:Mes_discussions
# #
# #Utilisation
# #Historique
# #Au_CWI
# #Au_CNRI
# #À_BeOpen
# #La_Python_Software_Foundation
# #Caractéristiques
# #Syntaxe
# #Mots-clés_du_langage
# #Types_de_base
# #Programmation_fonctionnelle
# #Programmation_objet
# #Méthodes_spéciales_et_définition_des_opérateurs
# #Générateurs
# #Réflexivité
# #Typage
# #Annotations
# #Compilation
# #Modèle_objet
# #Méthodes
# #Visibilité
# #Héritage
# #Bibliothèque_standard
# #Conventions_de_style
# #Interfaces_graphiques
# #La_communauté_Python
# #Adoption_de_Python
# #Implémentations_du_langage
# #Distributions_de_Python
# #Historique_des_versions
# #Développement
# #Les_PEP
# #Python_3
# #Philosophie
# #Planning_et_compatibilité
# #Python_pour_smartphones
# #Notes_et_références
# #Voir_aussi
# #Bibliographie
# #Liste_des_principaux_frameworks
# #Articles_connexes
# https://af.wikipedia.org/wiki/Python_(programmeertaal)
# https://als.wikipedia.org/wiki/Python_(Programmiersprache)
# https://an.wikipedia.org/wiki/Python
# https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D8%A9)
# https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8
# https://ast.wikipedia.org/wiki/Python
# https://az.wikipedia.org/wiki/Python_(proqramla%C5%9Fd%C4%B1rma_dili)
# https://azb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86
# https://ban.wikipedia.org/wiki/Python
# https://be.wikipedia.org/wiki/Python_(%D0%BC%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F)
# https://bg.wikipedia.org/wiki/Python
# https://bh.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8
# https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE)
# https://br.wikipedia.org/wiki/Python_(lavar_programmi%C3%B1)
# https://bs.wikipedia.org/wiki/Python_(programski_jezik)
# https://bug.wikipedia.org/wiki/Python
# https://ca.wikipedia.org/wiki/Python
# https://ceb.wikipedia.org/wiki/Python_(programming_language)
# https://ckb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%DB%86%D9%86_(%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D8%A8%DB%95%D8%B1%D9%86%D8%A7%D9%85%DB%95%D8%B3%D8%A7%D8%B2%DB%8C)
# https://cs.wikipedia.org/wiki/Python
# https://cy.wikipedia.org/wiki/Python_(iaith_raglennu)
# https://da.wikipedia.org/wiki/Python_(programmeringssprog)
# https://de.wikipedia.org/wiki/Python_(Programmiersprache)
# https://el.wikipedia.org/wiki/Python
# https://en.wikipedia.org/wiki/Python_(programming_language)
# https://eo.wikipedia.org/wiki/Python_(programlingvo)
# https://es.wikipedia.org/wiki/Python
# https://et.wikipedia.org/wiki/Python_(programmeerimiskeel)
# https://eu.wikipedia.org/wiki/Python_(informatika)
# https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86_(%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C)
# https://fi.wikipedia.org/wiki/Python_(ohjelmointikieli)
# https://fj.wikipedia.org/wiki/Python
# https://gl.wikipedia.org/wiki/Python
# https://gu.wikipedia.org/wiki/%E0%AA%AA%E0%AA%BE%E0%AA%AF%E0%AA%A5%E0%AB%8B%E0%AA%A8(%E0%AA%AA%E0%AB%8D%E0%AA%B0%E0%AB%8B%E0%AA%97%E0%AB%8D%E0%AA%B0%E0%AA%BE%E0%AA%AE%E0%AA%BF%E0%AA%82%E0%AA%97_%E0%AA%AD%E0%AA%BE%E0%AA%B7%E0%AA%BE)
# https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%99%D7%AA%D7%95%D7%9F
# https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8
# https://hr.wikipedia.org/wiki/Python_(programski_jezik)
# https://hu.wikipedia.org/wiki/Python_(programoz%C3%A1si_nyelv)
# https://hy.wikipedia.org/wiki/Python
# https://ia.wikipedia.org/wiki/Python_(linguage_de_programmation)
# https://id.wikipedia.org/wiki/Python_(bahasa_pemrograman)
# https://io.wikipedia.org/wiki/Python
# https://is.wikipedia.org/wiki/Python_(forritunarm%C3%A1l)
# https://it.wikipedia.org/wiki/Python
# https://ja.wikipedia.org/wiki/Python
# https://jbo.wikipedia.org/wiki/paiton
# https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%90%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90)
# https://kk.wikipedia.org/wiki/Python
# https://km.wikipedia.org/wiki/%E1%9E%95%E1%9E%B6%E1%9E%99%E1%9E%90%E1%9E%BB%E1%9E%93
# https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# https://ku.wikipedia.org/wiki/Python_(ziman%C3%AA_bernamesaziy%C3%AA)
# https://ky.wikipedia.org/wiki/Python
# https://la.wikipedia.org/wiki/Python_(lingua_programmandi)
# https://lmo.wikipedia.org/wiki/Python
# https://lt.wikipedia.org/wiki/Python
# https://lv.wikipedia.org/wiki/Python_(programm%C4%93%C5%A1anas_valoda)
# https://mk.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA)
# https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%88%E0%B4%A4%E0%B5%8D%E0%B4%A4%E0%B5%BA_(%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%99%E0%B5%8D%E0%B4%99%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7)
# https://mn.wikipedia.org/wiki/Python
# https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8
# https://ms.wikipedia.org/wiki/Python
# https://my.wikipedia.org/wiki/Python_(programming_language)
# https://nds.wikipedia.org/wiki/Python_(Programmeerspraak)
# https://nl.wikipedia.org/wiki/Python_(programmeertaal)
# https://nn.wikipedia.org/wiki/Python
# https://no.wikipedia.org/wiki/Python
# https://nqo.wikipedia.org/wiki/%DF%94%DF%8A%DF%8C%DF%95%DF%90%DF%B2%DF%AC
# https://or.wikipedia.org/wiki/%E0%AC%AA%E0%AC%BE%E0%AC%87%E0%AC%A5%E0%AC%A8%E0%AD%8D_(%E0%AC%AA%E0%AD%8D%E0%AC%B0%E0%AD%8B%E0%AC%97%E0%AD%8D%E0%AC%B0%E0%AC%BE%E0%AC%AE%E0%AC%BF%E0%AC%82_%E0%AC%AD%E0%AC%BE%E0%AC%B7%E0%AC%BE)
# https://pa.wikipedia.org/wiki/%E0%A8%AA%E0%A8%BE%E0%A8%88%E0%A8%A5%E0%A8%A8_(%E0%A8%AA%E0%A9%8D%E0%A8%B0%E0%A9%8B%E0%A8%97%E0%A8%B0%E0%A8%BE%E0%A8%AE%E0%A8%BF%E0%A9%B0%E0%A8%97_%E0%A8%AD%E0%A8%BE%E0%A8%B8%E0%A8%BC%E0%A8%BE)
# https://pl.wikipedia.org/wiki/Python
# https://pnb.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%DA%A9%D9%85%D9%BE%DB%8C%D9%88%D9%B9%D8%B1_%D8%A8%D9%88%D9%84%DB%8C)
# https://pt.wikipedia.org/wiki/Python
# https://qu.wikipedia.org/wiki/Python
# https://ro.wikipedia.org/wiki/Python
# https://ru.wikipedia.org/wiki/Python
# https://sah.wikipedia.org/wiki/Python
# https://sat.wikipedia.org/wiki/%E1%B1%AF%E1%B1%9F%E1%B1%AD%E1%B1%9B%E1%B1%B7%E1%B1%9A%E1%B1%B1(%E1%B1%AF%E1%B1%A8%E1%B1%B3%E1%B1%9C%E1%B1%BD%E1%B1%A8%E1%B1%9F%E1%B1%A2%E1%B1%A4%E1%B1%9D_%E1%B1%AF%E1%B1%9F%E1%B1%B9%E1%B1%A8%E1%B1%A5%E1%B1%A4)
# https://sco.wikipedia.org/wiki/Python_(programmin_leid)
# https://sh.wikipedia.org/wiki/Python_programski_jezik
# https://shn.wikipedia.org/wiki/Python_(programming_language)
# https://si.wikipedia.org/wiki/%E0%B6%B4%E0%B6%BA%E0%B7%92%E0%B6%AD%E0%B6%B1%E0%B7%8A
# https://simple.wikipedia.org/wiki/Python_(programming_language)
# https://sk.wikipedia.org/wiki/Python_(programovac%C3%AD_jazyk)
# https://sl.wikipedia.org/wiki/Python_(programski_jezik)
# https://sq.wikipedia.org/wiki/Python
# https://sr.wikipedia.org/wiki/Python_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA)
# https://sv.wikipedia.org/wiki/Python_(programspr%C3%A5k)
# https://sw.wikipedia.org/wiki/Python_(Lugha_ya_programu)
# https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%88%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AE%BE%E0%AE%A9%E0%AF%8D
# https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%88%E0%B0%A5%E0%B0%BE%E0%B0%A8%E0%B1%8D_(%E0%B0%95%E0%B0%82%E0%B0%AA%E0%B1%8D%E0%B0%AF%E0%B1%82%E0%B0%9F%E0%B0%B0%E0%B1%8D_%E0%B0%AD%E0%B0%BE%E0%B0%B7)
# https://tg.wikipedia.org/wiki/Python
# https://th.wikipedia.org/wiki/%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99_(%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%81%E0%B8%81%E0%B8%A3%E0%B8%A1)
# https://tl.wikipedia.org/wiki/Python_(wikang_pamprograma)
# https://tr.wikipedia.org/wiki/Python
# https://tt.wikipedia.org/wiki/Python
# https://ug.wikipedia.org/wiki/%D9%BE%D8%A7%D9%8A%D8%B3%D9%88%D9%86
# https://uk.wikipedia.org/wiki/Python
# https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%86%DA%AF_%D8%B2%D8%A8%D8%A7%D9%86)
# https://uz.wikipedia.org/wiki/Python
# https://vi.wikipedia.org/wiki/Python_(ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh)
# https://wa.wikipedia.org/wiki/Python_(lingaedje_%C3%A9ndjolike)
# https://war.wikipedia.org/wiki/Python_(programming_language)
# https://wuu.wikipedia.org/wiki/Python
# https://zh.wikipedia.org/wiki/Python
# https://zh-classical.wikipedia.org/wiki/%E7%9A%AE%E5%90%8C
# https://zh-min-nan.wikipedia.org/wiki/Python
# https://zh-yue.wikipedia.org/wiki/Python
# https://www.wikidata.org/wiki/Special:EntityPage/Q28865#sitelinks-wikipedia
# /wiki/Python_(langage)
# /wiki/Discussion:Python_(langage)
# /wiki/Python_(langage)
# /w/index.php?title=Python_(langage)&veaction=edit
# /w/index.php?title=Python_(langage)&action=edit
# /w/index.php?title=Python_(langage)&action=history
# /wiki/Python_(langage)
# /w/index.php?title=Python_(langage)&veaction=edit
# /w/index.php?title=Python_(langage)&action=edit
# /w/index.php?title=Python_(langage)&action=history
# /wiki/Sp%C3%A9cial:Pages_li%C3%A9es/Python_(langage)
# /wiki/Sp%C3%A9cial:Suivi_des_liens/Python_(langage)
# /wiki/Aide:Importer_un_fichier
# /wiki/Sp%C3%A9cial:Pages_sp%C3%A9ciales
# /w/index.php?title=Python_(langage)&oldid=207957017
# /w/index.php?title=Python_(langage)&action=info
# /w/index.php?title=Sp%C3%A9cial:Citer&page=Python_%28langage%29&id=207957017&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q28865
# /w/index.php?title=Sp%C3%A9cial:Livre&bookcmd=book_creator&referer=Python+%28langage%29
# /w/index.php?title=Sp%C3%A9cial:DownloadAsPdf&page=Python_%28langage%29&action=show-download-screen
# /w/index.php?title=Python_(langage)&printable=yes
# https://commons.wikimedia.org/wiki/Python_(programming_language)
# https://www.mediawiki.org/wiki/Python
# https://fr.wikibooks.org/wiki/Programmation_Python
# https://fr.wikiversity.org/wiki/Python
# /wiki/Aide:Homonymie
# /wiki/Python
# /wiki/Fichier:Python_logo_and_wordmark.svg
# /wiki/Fichier:CPT-TheoryOfComp-Binary-Search-Python.png
# #cite_note-1
# /wiki/Paradigme_(programmation)
# /wiki/Programmation_orient%C3%A9e_objet
# /wiki/Programmation_imp%C3%A9rative
# /wiki/Programmation_fonctionnelle
# /wiki/Guido_van_Rossum
# /wiki/Python_Software_Foundation
# /wiki/Version_d%27un_logiciel
# /wiki/24_octobre
# /wiki/Octobre_2022
# /wiki/2022
# #cite_note-wikidata-bcd8e158e3f5b675fc557c9f270c11eabeba2219-2
# /wiki/24_ao%C3%BBt
# /wiki/Ao%C3%BBt_2023
# /wiki/2023
# #cite_note-wikidata-817af25ea694c74af8fab2115091b7797719b643-3
# https://www.wikidata.org/wiki/Q28865?uselang=fr#P348
# /wiki/Version_d%27un_logiciel
# /wiki/6_septembre
# /wiki/Septembre_2023
# /wiki/2023
# #cite_note-wikidata-7f1901d9a11bdd21378e1289ebacb9f901e169b8-4
# https://www.wikidata.org/wiki/Q28865?uselang=fr#P348
# /wiki/Typage_fort
# /wiki/Typage_dynamique
# /wiki/Duck_typing
# /wiki/ABC_(langage)
# /wiki/C_(langage)
# /wiki/Eiffel_(langage)
# /wiki/ICON
# /wiki/Modula-3
# /wiki/Java_(langage)
# /wiki/Perl_(langage)
# /wiki/Smalltalk
# /wiki/Tool_Command_Language
# /wiki/Ruby
# /wiki/Groovy_(langage)
# /wiki/Boo_(langage)
# /wiki/Julia_(langage)
# /wiki/CPython
# /wiki/Jython
# /wiki/IronPython
# /wiki/PyPy
# /wiki/Langage_de_programmation
# /wiki/C_(langage)
# /wiki/Java_(langage)
# /wiki/C_sharp
# /wiki/Syst%C3%A8me_d%27exploitation
# /wiki/Logiciel_multiplateforme
# /wiki/Licence_de_logiciel
# /wiki/Licence_libre
# /wiki/Python_Software_Foundation_License
# /wiki/Site_web
# https://www.python.org/
# https://www.wikidata.org/wiki/Q28865?uselang=fr#P856
# /wiki/Extension_de_nom_de_fichier
# https://www.wikidata.org/wiki/Q28865?uselang=fr#P1195
# https://fr.wikipedia.org/w/index.php?title=Python_(langage)&action=edit&section=0
# /wiki/Mod%C3%A8le:Infobox_Langage_de_programmation
# /wiki/API_p
# /wiki/API_i
# /wiki/API_.
# /wiki/API_t
# /wiki/API_%C9%94%CC%83
# /wiki/Langage_de_programmation
# /wiki/Langage_interpr%C3%A9t%C3%A9
# /wiki/Paradigme_(programmation)
# /wiki/Plateforme_(informatique)
# /wiki/Programmation_imp%C3%A9rative
# /wiki/Programmation_structur%C3%A9e
# /wiki/Programmation_fonctionnelle
# /wiki/Programmation_orient%C3%A9e_objet
# /wiki/Typage_dynamique
# /wiki/Typage_fort
# /wiki/M%C3%A9moire_vive
# /wiki/Ramasse-miettes_(informatique)
# /wiki/Syst%C3%A8me_de_gestion_d%27exceptions
# /wiki/Perl_(langage)
# /wiki/Ruby
# /wiki/Scheme
# /wiki/Smalltalk
# /wiki/Tool_Command_Language
# /wiki/Licence_libre
# /wiki/Licence_BSD
# #cite_note-5
# /wiki/Plateforme_(informatique)
# /wiki/Smartphone
# /wiki/Ordinateur_central
# #cite_note-6
# /wiki/Windows
# /wiki/Unix
# /wiki/GNU/Linux
# /wiki/MacOS
# /wiki/Android
# /wiki/IOS_(Apple)
# /wiki/Java_(langage)
# /wiki/Microsoft_.NET
# /wiki/Langage_de_haut_niveau
# /wiki/Syntaxe
# /wiki/P%C3%A9dagogie
# /wiki/Langage_de_programmation
# /wiki/Langage_de_bas_niveau
# /wiki/Initiation
# #cite_note-7
# /w/index.php?title=Python_(langage)&veaction=edit&section=1
# /w/index.php?title=Python_(langage)&action=edit&section=1
# /wiki/Langage_de_programmation
# /wiki/Biblioth%C3%A8que_logicielle
# /wiki/Langage_de_script
# /wiki/Automatisme_(m%C3%A9canique)
# /wiki/Langage_de_script
# /wiki/Internet
# /wiki/Conception_assist%C3%A9e_par_ordinateur
# #Adoption_de_Python
# /wiki/Scientifique
# /wiki/Biblioth%C3%A8que_(informatique)
# /wiki/Calcul_num%C3%A9rique
# /w/index.php?title=Python_(langage)&veaction=edit&section=2
# /w/index.php?title=Python_(langage)&action=edit&section=2
# /w/index.php?title=Python_(langage)&veaction=edit&section=3
# /w/index.php?title=Python_(langage)&action=edit&section=3
# /wiki/Fichier:Guido_van_Rossum_OSCON_2006.jpg
# /wiki/OSCON
# /wiki/Ann%C3%A9es_1980
# /wiki/D%C3%A9veloppeur
# /wiki/Guido_van_Rossum
# /wiki/ABC_(langage)
# /wiki/Centrum_voor_Wiskunde_en_Informatica
# /wiki/Amsterdam
# /wiki/Pays-Bas
# /wiki/Syst%C3%A8me_d%27exploitation
# /wiki/Amoeba_(syst%C3%A8me_d%27exploitation)
# /wiki/Appel_syst%C3%A8me
# /wiki/Bourne_shell
# /wiki/Interface_utilisateur
# /wiki/Interpr%C3%A9teur_de_commandes
# #cite_note-FAQ1.2-8
# /wiki/1989
# /wiki/No%C3%ABl
# /wiki/Ordinateur_personnel
# #cite_note-9
# /wiki/S%C3%A9rie_t%C3%A9l%C3%A9vis%C3%A9e
# /wiki/Monty_Python%27s_Flying_Circus
# #cite_note-10
# /wiki/Indentation_comme_syntaxe
# /wiki/Modula-3
# /wiki/Syst%C3%A8me_de_gestion_d%27exceptions
# /wiki/Langage_C
# /wiki/Unix
# #cite_note-11
# #cite_note-12
# /wiki/Usenet
# /w/index.php?title=Python_(langage)&veaction=edit&section=4
# /w/index.php?title=Python_(langage)&action=edit&section=4
# /wiki/1995
# /w/index.php?title=Corporation_for_National_Research_Initiatives&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Corporation_for_National_Research_Initiatives
# /wiki/Reston_(Virginie)
# /wiki/%C3%89tats-Unis
# /wiki/Ao%C3%BBt_1995
# /wiki/1995_en_informatique
# #cite_note-13
# /wiki/Navigateur_web
# /wiki/Tk_(informatique)
# /wiki/HotJava
# /wiki/Applet
# #cite_note-14
# /wiki/Plugin
# #cite_note-15
# #cite_note-16
# #cite_note-17
# #cite_note-18
# /wiki/1999
# #cite_note-19
# /wiki/Defense_Advanced_Research_Projects_Agency
# /wiki/Programmation_informatique
# /wiki/Environnement_de_d%C3%A9veloppement
# /wiki/IDLE_(Python)
# #cite_note-20
# /w/index.php?title=Python_(langage)&veaction=edit&section=5
# /w/index.php?title=Python_(langage)&action=edit&section=5
# /wiki/2000
# /w/index.php?title=BeOpen.com&action=edit&redlink=1
# /w/index.php?title=PythonLabs&action=edit&redlink=1
# /wiki/Zope
# #cite_note-21
# #cite_note-22
# #cite_note-23
# #cite_note-24
# /w/index.php?title=Python_(langage)&veaction=edit&section=6
# /w/index.php?title=Python_(langage)&action=edit&section=6
# /wiki/Python_Software_Foundation_License
# /wiki/Programmation_informatique
# /wiki/Python_Software_Foundation
# /wiki/Association_sans_but_lucratif
# /wiki/Apache_Software_Foundation
# /wiki/Programmation_orient%C3%A9e_objet
# /wiki/Classe_(informatique)
# /w/index.php?title=Python_(langage)&veaction=edit&section=7
# /w/index.php?title=Python_(langage)&action=edit&section=7
# /w/index.php?title=Python_(langage)&veaction=edit&section=8
# /w/index.php?title=Python_(langage)&action=edit&section=8
# /wiki/Syntaxe
# /wiki/C_(langage)
# /wiki/Perl_(langage)
# /wiki/Pascal_(langage)
# /wiki/Croisillon_(signe)
# /wiki/Bloc_de_base
# /wiki/Style_d%27indentation
# /wiki/C_(langage)
# /wiki/C%2B%2B
# /wiki/Pascal_(langage)
# /wiki/Ruby
# /wiki/Indentation_comme_syntaxe
# #cite_note-25
# #cite_note-pep8-26
# /wiki/Factorielle
# /wiki/Factorielle
# #cite_note-27
# /w/index.php?title=Python_(langage)&veaction=edit&section=9
# /w/index.php?title=Python_(langage)&action=edit&section=9
# #cite_note-28
# #cite_note-29
# #cite_note-30
# #cite_note-31
# /wiki/Port%C3%A9e_(informatique)
# /wiki/Objet_immuable
# /w/index.php?title=Python_(langage)&veaction=edit&section=10
# /w/index.php?title=Python_(langage)&action=edit&section=10
# /wiki/Entier_relatif
# /wiki/Conversion_de_type
# /wiki/D%C3%A9passement_de_pile
# /wiki/Virgule_flottante
# /wiki/IEEE_754
# /wiki/Nombre_complexe
# /wiki/N-uplet
# /wiki/Objet_immuable
# /wiki/Tableau_crois%C3%A9_dynamique
# /wiki/Tableau_associatif
# /wiki/Unicode
# /wiki/Octet
# #cite_note-32
# /wiki/Unicode
# /wiki/Objet_immuable
# /wiki/Objet_immuable
# /w/index.php?title=Python_(langage)&veaction=edit&section=11
# /w/index.php?title=Python_(langage)&action=edit&section=11
# /wiki/Programmation_fonctionnelle
# /wiki/Liste_en_compr%C3%A9hension
# /wiki/Tableau_associatif
# /wiki/Ensemble_(informatique)
# #cite_note-33
# /wiki/Entier_naturel
# /wiki/American_Standard_Code_for_Information_Interchange
# /wiki/Fonction_anonyme
# /wiki/Fermeture_(informatique)
# /w/index.php?title=Python_(langage)&veaction=edit&section=12
# /w/index.php?title=Python_(langage)&action=edit&section=12
# /wiki/Instance_(programmation)
# /wiki/C%2B%2B
# /wiki/Java_(langage)
# /wiki/Classe_(informatique)
# /wiki/H%C3%A9ritage_multiple
# /w/index.php?title=Python_(langage)&veaction=edit&section=13
# /w/index.php?title=Python_(langage)&action=edit&section=13
# /wiki/Programmation_orient%C3%A9e_objet
# #cite_note-34
# /w/index.php?title=Python_(langage)&veaction=edit&section=14
# /w/index.php?title=Python_(langage)&action=edit&section=14
# /wiki/Suite_de_Fibonacci
# #cite_note-35
# /wiki/Probl%C3%A8me_des_huit_dames
# /wiki/Effet_de_bord_(informatique)
# /w/index.php?title=Python_(langage)&veaction=edit&section=15
# /w/index.php?title=Python_(langage)&action=edit&section=15
# /wiki/Table_de_hachage
# /wiki/Introspection_(informatique)
# /wiki/Intercession_(informatique)
# /w/index.php?title=Python_(langage)&veaction=edit&section=16
# /w/index.php?title=Python_(langage)&action=edit&section=16
# /wiki/Fichier:Python_3._The_standard_type_hierarchy.png
# /wiki/Typage
# /wiki/Duck_typing
# /wiki/Signature_de_type
# /wiki/Typage_statique
# #cite_note-36
# /wiki/Patron_de_conception
# /w/index.php?title=Python_(langage)&veaction=edit&section=17
# /w/index.php?title=Python_(langage)&action=edit&section=17
# #cite_note-37
# #cite_note-38
# #cite_note-39
# #cite_note-40
# /w/index.php?title=Python_(langage)&veaction=edit&section=18
# /w/index.php?title=Python_(langage)&action=edit&section=18
# #cite_note-41
# #cite_note-42
# /wiki/Bytecode
# #cite_note-43
# /wiki/Unix
# /wiki/Microsoft_Windows
# /wiki/MacOS
# #cite_note-44
# /wiki/MacOS
# /wiki/Py2exe
# /wiki/Microsoft_Windows
# /w/index.php?title=Python_(langage)&veaction=edit&section=19
# /w/index.php?title=Python_(langage)&action=edit&section=19
# /wiki/R%C3%A9f%C3%A9rence_(informatique)
# #cite_note-45
# /w/index.php?title=Python_(langage)&veaction=edit&section=20
# /w/index.php?title=Python_(langage)&action=edit&section=20
# #cite_note-46
# #cite_note-47
# /w/index.php?title=Python_(langage)&veaction=edit&section=21
# /w/index.php?title=Python_(langage)&action=edit&section=21
# /wiki/Encapsulation_(programmation)
# /wiki/S%C3%A9curit%C3%A9_du_syst%C3%A8me_d%27information
# #cite_note-48
# /wiki/Accesseur
# /w/index.php?title=Python_(langage)&veaction=edit&section=22
# /w/index.php?title=Python_(langage)&action=edit&section=22
# /wiki/H%C3%A9ritage_multiple
# /wiki/Lin%C3%A9arisation_C3
# /wiki/Dylan_(langage)
# #cite_note-49
# /w/index.php?title=Ordre_de_r%C3%A9solution_de_m%C3%A9thode&action=edit&redlink=1
# /wiki/Algorithme_de_parcours_en_profondeur
# /wiki/H%C3%A9ritage_en_diamant
# #cite_note-50
# /w/index.php?title=Python_(langage)&veaction=edit&section=23
# /w/index.php?title=Python_(langage)&action=edit&section=23
# /wiki/Fichier:Python_batteries_included.jpg
# /wiki/Biblioth%C3%A8que_standard
# /wiki/MIME
# /wiki/HTTP
# /wiki/Interface_graphique
# /wiki/Expression_rationnelle
# /wiki/Framework
# /wiki/Test_unitaire
# /wiki/PyUnit
# /w/index.php?title=Python_(langage)&veaction=edit&section=24
# /w/index.php?title=Python_(langage)&action=edit&section=24
# /wiki/Guido_van_Rossum
# #cite_note-pep8-26
# /wiki/Google
# #cite_note-51
# /w/index.php?title=Python_(langage)&veaction=edit&section=25
# /w/index.php?title=Python_(langage)&action=edit&section=25
# /wiki/Interface_graphique
# /wiki/Tkinter
# /wiki/Biblioth%C3%A8ques_logicielles
# /wiki/Toolkit
# /wiki/Syst%C3%A8me_d%27exploitation
# /wiki/Tkinter
# #cite_note-52
# /wiki/Tk_(informatique)
# /wiki/WxPython
# /wiki/WxWidgets
# /wiki/PyGTK
# /wiki/GTK_(bo%C3%AEte_%C3%A0_outils)
# /wiki/PyQt
# /wiki/PySide
# /wiki/Qt
# /wiki/FOX_Toolkit
# /wiki/Simple_DirectMedia_Layer
# /wiki/Pygame
# /wiki/Binding
# /wiki/SFML
# /w/index.php?title=Pyglet&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Pyglet
# /wiki/Silverlight
# /wiki/IronPython
# /w/index.php?title=Python_(langage)&veaction=edit&section=26
# /w/index.php?title=Python_(langage)&action=edit&section=26
# /wiki/Guido_van_Rossum
# /wiki/Benevolent_Dictator_for_Life
# #cite_note-53
# #cite_note-54
# /wiki/Roundup_(bugtracker)
# /wiki/SourceForge_(logiciel)
# /wiki/Variable_m%C3%A9tasyntaxique
# /wiki/Spam_(sketch)
# /wiki/Monty_Python
# /wiki/SPAM
# /wiki/Spam
# /w/index.php?title=Python_(langage)&veaction=edit&section=27
# /w/index.php?title=Python_(langage)&action=edit&section=27
# /wiki/Liste_de_logiciels_Python
# #cite_note-55
# /wiki/Google
# /wiki/Guido_van_Rossum
# #cite_note-56
# /wiki/Industrial_Light_%26_Magic
# /wiki/National_Aeronautics_and_Space_Administration
# /wiki/Jeu_vid%C3%A9o
# /wiki/EVE_Online
# /wiki/FreeCAD
# /wiki/Conception_assist%C3%A9e_par_ordinateur
# /wiki/Blender
# /wiki/Mod%C3%A9lisation_tridimensionnelle
# /wiki/Montage_vid%C3%A9o
# /wiki/Inkscape
# /wiki/Image_vectorielle
# /wiki/LibreOffice
# /wiki/Apache_OpenOffice
# /wiki/Suite_bureautique
# /wiki/StarOffice
# /w/index.php?title=Portage_(logiciel)&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Portage_(software)
# /wiki/Syst%C3%A8me_d%27exploitation
# /wiki/Gentoo
# /wiki/ParaView
# /wiki/Donn%C3%A9e_num%C3%A9rique
# /wiki/Kodi_Entertainment_Center
# /wiki/Lecteur_multim%C3%A9dia
# /wiki/QGIS
# /wiki/Cartographie
# /wiki/Weblate
# /wiki/Traduction
# /wiki/Gedit
# /wiki/SageMath
# /wiki/Wing_IDE
# /wiki/Environnement_de_d%C3%A9veloppement_int%C3%A9gr%C3%A9
# /wiki/Corel_Paint_Shop_Pro
# /wiki/Capella_(notation_musicale)
# /wiki/ArcGIS
# #cite_note-57
# #cite_note-58
# /wiki/Classes_pr%C3%A9paratoires_scientifiques
# /wiki/Caml
# /wiki/Pascal_(langage)
# /wiki/OCaml
# #cite_note-59
# #cite_note-60
# /w/index.php?title=Python_(langage)&veaction=edit&section=28
# /w/index.php?title=Python_(langage)&action=edit&section=28
# /wiki/CPython
# /wiki/C_(langage)
# #cite_note-61
# /wiki/Stackless_Python
# /wiki/Pile_d%27ex%C3%A9cution
# /wiki/Jython
# /wiki/Interpr%C3%A8te_(informatique)
# /wiki/Machine_virtuelle_Java
# /wiki/Environnement_de_d%C3%A9veloppement
# /wiki/Java_(langage)
# /wiki/IronPython
# /wiki/Microsoft_.NET
# /wiki/Mono_(informatique)
# #cite_note-62
# /wiki/MicroPython
# /wiki/Microcontr%C3%B4leur
# /wiki/PyPy
# /wiki/C_(langage)
# /wiki/LLVM
# /wiki/Compilateur
# /wiki/Parrot_(machine_virtuelle)
# /wiki/Machine_virtuelle
# /wiki/Perl_(langage)
# /wiki/Shed_Skin
# #cite_note-63
# /wiki/Compilateur
# /wiki/C%2B%2B
# /w/index.php?title=Unladen_Swallow&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Unladen_Swallow
# #cite_note-64
# /wiki/Rust_(langage)
# #cite_note-65
# /wiki/Apache_Spark
# /w/index.php?title=Python_(langage)&veaction=edit&section=29
# /w/index.php?title=Python_(langage)&action=edit&section=29
# #cite_note-66
# #cite_note-67
# #cite_note-68
# /wiki/Qt
# /wiki/Eclipse_(projet)
# #cite_note-69
# /wiki/Anaconda_(Python_distribution)
# #cite_note-70
# /wiki/Intel
# #cite_note-71
# /w/index.php?title=Math_Kernel_Library&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Math_Kernel_Library
# /wiki/NumPy
# /wiki/SciPy
# /wiki/Intel_Parallel_Studio
# #cite_note-72
# #cite_note-73
# /wiki/Spyder_(logiciel)
# /w/index.php?title=Python_(langage)&veaction=edit&section=30
# /w/index.php?title=Python_(langage)&action=edit&section=30
# #cite_note-74
# /wiki/3_janvier
# /wiki/Janvier_1998
# /wiki/1998_en_informatique
# /wiki/Expression_rationnelle
# /wiki/5_septembre
# /wiki/Septembre_2000
# /wiki/2000_en_informatique
# /wiki/16_octobre
# /wiki/Octobre_2000
# /wiki/2000_en_informatique
# /wiki/Ramasse-miettes_(informatique)
# /wiki/15_avril
# /wiki/Avril_2001
# /wiki/2001_en_informatique
# /wiki/Introspection_(informatique)
# /wiki/Commentaire_(informatique)
# /wiki/M%C3%A9thode_agile
# /wiki/Pyunit
# /wiki/Juin_2001
# /wiki/2001_en_informatique
# /wiki/Licence_publique_g%C3%A9n%C3%A9rale_GNU
# /wiki/21_d%C3%A9cembre
# /wiki/D%C3%A9cembre_2001
# /wiki/2001_en_informatique
# /wiki/It%C3%A9rateur_(motif_de_conception)
# /wiki/G%C3%A9n%C3%A9rateur_(informatique)
# /wiki/29_juin
# /wiki/Juin_2003
# /wiki/2003_en_informatique
# /wiki/Alg%C3%A8bre_de_Boole_(logique)
# /wiki/Unicode
# /wiki/30_novembre
# /wiki/Novembre_2004
# /wiki/2004_en_informatique
# /wiki/19_septembre
# /wiki/Septembre_2006
# /wiki/2006_en_informatique
# /wiki/1er_octobre
# /wiki/Octobre_2008
# /wiki/2008_en_informatique
# /wiki/JSON
# /wiki/3_juillet
# /wiki/Juillet_2010
# /wiki/2010_en_informatique
# /wiki/3_d%C3%A9cembre
# /wiki/D%C3%A9cembre_2008
# /wiki/2008_en_informatique
# #cite_note-75
# https://www.python.org/dev/peps/pep-3100/
# /wiki/27_juin
# /wiki/Juin_2009
# /wiki/2009_en_informatique
# #cite_note-76
# /wiki/20_f%C3%A9vrier
# /wiki/F%C3%A9vrier_2011
# /wiki/2011_en_informatique
# #cite_note-77
# /wiki/29_septembre
# /wiki/Septembre_2012
# /wiki/2012_en_informatique
# #cite_note-py3-78
# #cite_note-py3-78
# #cite_note-79
# /wiki/LZMA
# /wiki/Mock_(programmation_orient%C3%A9e_objet)
# /wiki/16_mars
# /wiki/Mars_2014
# /wiki/2014_en_informatique
# #cite_note-py34-80
# #cite_note-81
# /wiki/13_septembre
# /wiki/Septembre_2015
# /wiki/2015_en_informatique
# #cite_note-py35-82
# #cite_note-83
# #cite_note-84
# #cite_note-85
# /wiki/G%C3%A9n%C3%A9rateur_de_nombres_pseudo-al%C3%A9atoires
# #cite_note-86
# #cite_note-87
# #cite_note-whatsnew_3.7-88
# #cite_note-whatsnew_3.7-88
# #cite_note-89
# #cite_note-90
# #cite_note-91
# #cite_note-92
# /wiki/Fichier:Fairytale_warning.png
# /wiki/Sp%C3%A9cial:EditPage/Python_(langage)
# /wiki/Aide:Comment_modifier_une_page
# #cite_note-93
# #cite_note-94
# #cite_note-95
# #cite_note-96
# #cite_note-97
# #cite_note-98
# #cite_note-99
# #cite_note-100
# #cite_note-101
# #cite_note-102
# #cite_note-103
# #cite_note-104
# #cite_note-105
# #cite_note-106
# /wiki/Fichier:Fairytale_warning.png
# /wiki/Sp%C3%A9cial:EditPage/Python_(langage)
# /wiki/Aide:Comment_modifier_une_page
# /w/index.php?title=Python_(langage)&veaction=edit&section=31
# /w/index.php?title=Python_(langage)&action=edit&section=31
# /w/index.php?title=Python_(langage)&veaction=edit&section=32
# /w/index.php?title=Python_(langage)&action=edit&section=32
# #cite_note-107
# #cite_note-108
# #cite_note-109
# /w/index.php?title=Python_(langage)&veaction=edit&section=33
# /w/index.php?title=Python_(langage)&action=edit&section=33
# #cite_note-autogenerated1-110
# #cite_note-111
# #cite_note-112
# /wiki/Casio
# /wiki/NumWorks
# /wiki/Texas_Instruments
# #cite_note-113
# /wiki/Ordinateurs_personnels
# /w/index.php?title=Python_(langage)&veaction=edit&section=34
# /w/index.php?title=Python_(langage)&action=edit&section=34
# #cite_note-114
# /w/index.php?title=Python_(langage)&veaction=edit&section=35
# /w/index.php?title=Python_(langage)&action=edit&section=35
# #cite_note-115
# /wiki/Perl_6
# #cite_note-116
# #cite_note-117
# /w/index.php?title=Python_(langage)&veaction=edit&section=36
# /w/index.php?title=Python_(langage)&action=edit&section=36
# /wiki/Android
# /wiki/IPhone
# /wiki/Jailbreak_d%27iOS
# /wiki/IOS_(Apple)
# /w/index.php?title=SL4A&action=edit&redlink=1
# /wiki/Interface_graphique
# /wiki/SMS
# #cite_note-118
# /wiki/BlackBerry_(soci%C3%A9t%C3%A9)
# /wiki/BlackBerry_OS
# #cite_note-119
# #cite_note-120
# #cite_note-121
# /w/index.php?title=Python_(langage)&veaction=edit&section=37
# /w/index.php?title=Python_(langage)&action=edit&section=37
# #cite_ref-1
# http://python-history.blogspot.com/2009/01/brief-timeline-of-python.html
# /w/index.php?title=Blogger_(service)&action=edit&redlink=1
# #cite_ref-wikidata-bcd8e158e3f5b675fc557c9f270c11eabeba2219_2-0
# https://endoflife.date/python
# #cite_ref-wikidata-817af25ea694c74af8fab2115091b7797719b643_3-0
# https://blog.python.org/2023/08/python-3115-31013-3918-and-3818-is-now.html
# #cite_ref-wikidata-7f1901d9a11bdd21378e1289ebacb9f901e169b8_4-0
# https://pythoninsider.blogspot.com/2023/09/python-3120-release-candidate-2-now.html
# #cite_ref-5
# https://www.python.org/psf/license/
# #cite_ref-6
# https://www.python.org/download/other/
# #cite_ref-7
# http://www.greenteapress.com/thinkpython/thinkCSpy/html/preface.html
# #cite_ref-FAQ1.2_8-0
# https://www.python.org/doc/faq/general/#why-was-python-created-in-the-first-place
# #cite_ref-9
# http://homepages.cwi.nl/~jack/macpython/intro.html
# #cite_ref-10
# /wiki/International_Standard_Book_Number
# /wiki/Sp%C3%A9cial:Ouvrages_de_r%C3%A9f%C3%A9rence/978-1-4493-7932-2
# https://books.google.fr/books?id=1HxWGezDZcgC
# #cite_ref-11
# https://www.python.org/doc/essays/foreword/
# #cite_ref-12
# http://svn.python.org/projects/python/trunk/Misc/HISTORY
# https://groups.google.com/group/alt.sources/browse_thread/thread/3b6652abb0e23b03/53ee3620bc53c281
# /wiki/Tar_(informatique)
# https://www.python.org/download/releases/early/
# #cite_ref-13
# http://grail.sourceforge.net/info/team.html
# #cite_ref-14
# http://grail.sourceforge.net/info/papers/restofus.html
# #cite_ref-15
# https://docs.python.org/lib/module-rexec.html
# #cite_ref-16
# https://docs.python.org/2/library/htmllib.html
# #cite_ref-17
# http://grail.sourceforge.net/info/diagram.gif
# #cite_ref-18
# http://grail.sourceforge.net/
# #cite_ref-19
# https://www.python.org/doc/essays/cp4e/
# #cite_ref-20
# https://www.python.org/doc/essays/cp4e
# #cite_ref-21
# https://docs.python.org/2/license.html
# #cite_ref-22
# https://mail.python.org/pipermail/python-list/1999-December/014104.html
# #cite_ref-23
# https://web.archive.org/web/20031002184114/www.amk.ca/python/writing/warts.html
# #cite_ref-24
# https://www.python.org/download/releases/2.2.3/descrintro/
# #cite_ref-25
# https://www.python.org/dev/peps/pep-0008/
# #cite_ref-pep8_26-0
# #cite_ref-pep8_26-1
# https://www.python.org/dev/peps/pep-0008/
# #cite_ref-27
# https://www.python.org/dev/peps/pep-0308/
# #cite_ref-28
# https://docs.python.org/fr/3/library/keyword.html
# #cite_ref-29
# https://docs.python.org/fr/3/library/functions.html#built-in-funcs
# #cite_ref-30
# https://wiki.python.org/moin/Python3.0
# #cite_ref-31
# https://www.python.org/dev/peps/pep-3104/
# #cite_ref-32
# https://www.python.org/dev/peps/pep-0358/
# https://www.python.org/dev/peps/pep-3137/
# #cite_ref-33
# https://www.python.org/dev/peps/pep-0202/
# https://www.python.org/dev/peps/pep-0274/
# #cite_ref-34
# https://docs.python.org/3/fr/reference/datamodel.html#specialnames
# #cite_ref-35
# https://www.python.org/dev/peps/pep-0380/
# #cite_ref-36
# https://pypi.python.org/pypi/traits
# #cite_ref-37
# https://www.python.org/dev/peps/pep-3107/
# #cite_ref-38
# https://www.python.org/dev/peps/pep-3107/#fundamentals-of-function-annotations
# #cite_ref-39
# https://docs.python.org/fr/3/library/typing.html
# #cite_ref-40
# https://www.python.org/dev/peps/pep-0484/
# #cite_ref-41
# http://www.pylint.org
# #cite_ref-42
# http://mypy-lang.org/
# #cite_ref-43
# http://www.pyinstaller.org//
# #cite_ref-44
# http://svn.pythonmac.org/py2app/py2app/trunk/doc/index.html#abstract
# #cite_ref-45
# http://www.diveintopython3.net/your-first-python-program.html#everythingisanobject
# #cite_ref-46
# https://docs.python.org/tut/node11.html
# #cite_ref-47
# http://effbot.org/pyfaq/why-must-self-be-used-explicitly-in-method-definitions-and-calls.htm
# #cite_ref-48
# http://www.mactech.com/articles/mactech/Vol.20/20.11/PythonForAppleScripters/index.html
# #cite_ref-49
# /wiki/Digital_Object_Identifier
# https://dx.doi.org/10.1145/236337.236343
# http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.19.3910
# #cite_ref-50
# https://www.python.org/download/releases/2.3/mro/
# #cite_ref-51
# https://google.github.io/styleguide/pyguide.html
# #cite_ref-52
# http://pmw.sourceforge.net/
# #cite_ref-53
# https://www.mail-archive.com/python-committers@python.org/msg05628.html
# #cite_ref-54
# https://discuss.python.org/t/steering-council-nomination-guido-van-rossum-2020-term/2657/11
# #cite_ref-55
# https://www.python.org/about/quotes/
# #cite_ref-56
# http://www.oreillynet.com/onlamp/blog/2005/12/python_creator_guido_van_rossu.html
# #cite_ref-57
# http://resources.arcgis.com/en/communities/python/
# #cite_ref-58
# http://cache.media.education.gouv.fr/file/special_3_ESR/50/5/programme-informatique_252505.pdf
# http://www.education.gouv.fr/
# #cite_ref-59
# http://www.mines-ponts.fr/pages/upload/sujet/sujet.php
# #cite_ref-60
# https://www.concours-centrale-supelec.fr/CentraleSupelec
# #cite_ref-61
# https://wiki.python.org/moin/PythonImplementations
# #cite_ref-62
# https://brython.info/
# #cite_ref-63
# https://code.google.com/archive/p/shedskin
# #cite_ref-64
# https://code.google.com/archive/p/unladen-swallow
# #cite_ref-65
# https://github.com/RustPython/RustPython
# #cite_ref-66
# https://wiki.python.org/moin/PythonDistributions
# #cite_ref-67
# http://www.activestate.com/activepython
# #cite_ref-68
# https://python-xy.github.io
# #cite_ref-69
# https://www.enthought.com/
# #cite_ref-70
# http://continuum.io/
# #cite_ref-71
# https://software.intel.com/en-us/intel-distribution-for-python
# #cite_ref-72
# http://www.pyzo.org/
# #cite_ref-73
# https://winpython.github.io
# #cite_ref-74
# https://docs.python.org/fr/3/whatsnew/
# #cite_ref-75
# https://www.python.org/download/releases/3.0/
# #cite_ref-76
# https://www.python.org/download/releases/3.1/
# #cite_ref-77
# https://www.python.org/download/releases/3.2/
# #cite_ref-py3_78-0
# #cite_ref-py3_78-1
# https://www.python.org/download/releases/3.3.0/
# #cite_ref-79
# https://www.python.org/dev/peps/pep-0380/
# #cite_ref-py34_80-0
# https://www.python.org/download/releases/3.4.0/
# #cite_ref-81
# https://docs.python.org/fr/3/whatsnew/3.4.html
# #cite_ref-py35_82-0
# https://www.python.org/download/releases/3.5.0/
# #cite_ref-83
# https://docs.python.org/fr/3/whatsnew/3.5.html
# #cite_ref-84
# https://www.python.org/downloads/release/python-360/
# #cite_ref-85
# https://www.python.org/dev/peps/pep-0515/
# #cite_ref-86
# https://www.python.org/dev/peps/pep-0506/
# #cite_ref-87
# https://www.python.org/dev/peps/pep-0498/
# #cite_ref-whatsnew_3.7_88-0
# #cite_ref-whatsnew_3.7_88-1
# https://docs.python.org/3.7/whatsnew/3.7.html
# #cite_ref-89
# https://docs.python.org/fr/3/library/contextvars.html
# #cite_ref-90
# https://docs.python.org/fr/3/library/asyncio-task.html#awaitables
# #cite_ref-91
# https://www.python.org/dev/peps/pep-0553/
# #cite_ref-92
# https://docs.python.org/fr/3/library/time.html#time.time_ns
# #cite_ref-93
# https://www.python.org/dev/peps/pep-0584/
# #cite_ref-94
# https://www.python.org/dev/peps/pep-0616/
# #cite_ref-95
# https://www.python.org/dev/peps/pep-0615/
# #cite_ref-96
# https://www.python.org/dev/peps/pep-0585/
# #cite_ref-97
# https://www.python.org/dev/peps/pep-0602/
# #cite_ref-98
# https://docs.python.org/3/whatsnew/3.9.html
# #cite_ref-99
# https://www.python.org/dev/peps/pep-0604/
# #cite_ref-100
# https://www.python.org/dev/peps/pep-0612/
# #cite_ref-101
# https://www.python.org/dev/peps/pep-0613/
# #cite_ref-102
# https://www.python.org/dev/peps/pep-0618/
# #cite_ref-103
# https://www.python.org/dev/peps/pep-0626/
# #cite_ref-104
# https://www.python.org/dev/peps/pep-0634/
# #cite_ref-105
# https://www.python.org/dev/peps/pep-0635/
# #cite_ref-106
# https://www.python.org/dev/peps/pep-0636/
# #cite_ref-107
# https://www.docstring.fr/glossaire/pep/
# #cite_ref-108
# https://www.python.org/dev/peps/
# #cite_ref-109
# https://www.python.org/dev/peps/pep-0008/
# #cite_ref-autogenerated1_110-0
# https://python.org/download/releases/3.0/
# #cite_ref-111
# https://www.python.org/peps/pep-3000.html
# #cite_ref-112
# https://wiki.python.org/moin/Python2orPython3
# #cite_ref-113
# /wiki/France
# #cite_ref-114
# https://www.docstring.fr/glossaire/print/
# #cite_ref-115
# https://www.python.org/dev/peps/pep-3000/
# #cite_ref-116
# http://intertwingly.net/blog/2007/09/01/2to3
# #cite_ref-117
# https://www.python.org/dev/peps/pep-0361/
# #cite_ref-118
# https://code.google.com/p/android-scripting/
# #cite_ref-119
# http://blackberry-py.microcode.ca/
# #cite_ref-120
# http://hg.microcode.ca/blackberry-py/wiki/Home
# /wiki/Bitbucket
# #cite_ref-121
# http://peterhansen.ca/blog/blackberry-tart-preview.html
# /w/index.php?title=Python_(langage)&veaction=edit&section=38
# /w/index.php?title=Python_(langage)&action=edit&section=38
# https://commons.wikimedia.org/wiki/Category:Python_(programming_language)?uselang=fr
# https://fr.wiktionary.org/wiki/Python
# https://fr.wikiversity.org/wiki/Python
# https://fr.wikibooks.org/wiki/Cat%C3%A9gorie:Python
# /w/index.php?title=Python_(langage)&veaction=edit&section=39
# /w/index.php?title=Python_(langage)&action=edit&section=39
# /wiki/Addison-Wesley
# /wiki/O%27Reilly_Media
# /wiki/O%27Reilly_Media
# /w/index.php?title=Python_(langage)&veaction=edit&section=40
# /w/index.php?title=Python_(langage)&action=edit&section=40
# /wiki/NumPy
# /wiki/SciPy
# /wiki/Pandas
# /wiki/International_Mathematics_and_Statistics_Library
# /wiki/Sympy
# /wiki/SageMath
# /wiki/Syst%C3%A8me_expert
# /w/index.php?title=PyCLIPS&action=edit&redlink=1
# /w/index.php?title=Pyswip&action=edit&redlink=1
# /w/index.php?title=Pydot&action=edit&redlink=1
# /wiki/Matplotlib
# /w/index.php?title=Pyngl&action=edit&redlink=1
# /w/index.php?title=MayaVi&action=edit&redlink=1
# /wiki/Exploration_de_donn%C3%A9es
# /wiki/Orange_(logiciel)
# /w/index.php?title=SimPy&action=edit&redlink=1
# /wiki/PyMOL
# /w/index.php?title=MMTK&action=edit&redlink=1
# /wiki/Chimera_(logiciel)
# /w/index.php?title=PyQuante&action=edit&redlink=1
# /w/index.php?title=Biopython&action=edit&redlink=1
# /wiki/Logiciel_utilitaire
# /w/index.php?title=EGenix&action=edit&redlink=1
# /w/index.php?title=Ctype&action=edit&redlink=1
# /wiki/Analyse_syntaxique
# /w/index.php?title=PyParsing&action=edit&redlink=1
# /wiki/PLY_(Python_Lex-Yacc)
# /wiki/NLTK
# /wiki/SpaCy
# /wiki/G%C3%A9n%C3%A9rateur_de_documentation
# /wiki/Sphinx_(g%C3%A9n%C3%A9rateur_de_documentation)
# /wiki/Python_Imaging_Library
# /wiki/Soya_3D
# /w/index.php?title=Vpython&action=edit&redlink=1
# /w/index.php?title=Pymedia&action=edit&redlink=1
# /wiki/NodeBox
# /wiki/Pygame
# /wiki/Panda3D
# /wiki/Framework
# /wiki/Django_(framework)
# /w/index.php?title=Karrigell&action=edit&redlink=1
# /w/index.php?title=Grok_(framework)&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Grok_(framework)
# /wiki/TurboGears
# /w/index.php?title=Pylons&action=edit&redlink=1
# https://en.wikipedia.org/wiki/Pylons_project
# /wiki/Flask_(framework)
# /wiki/Bottle_(framework)
# /wiki/Serveur_HTTP
# /wiki/Syst%C3%A8me_de_gestion_de_contenu
# /wiki/Plone
# /wiki/Zope
# /wiki/Google_App_Engine
# /wiki/CherryPy
# /wiki/MoinMoin
# /wiki/Django_CMS
# /wiki/Syst%C3%A8me_d%27information_g%C3%A9ographique
# /wiki/S%C3%A9rialisation
# /w/index.php?title=SimpleJSON&action=edit&redlink=1
# /wiki/Transmission_Control_Protocol
# /wiki/User_Datagram_Protocol
# /wiki/Secure_Sockets_Layer
# /wiki/Transport_Layer_Security
# /wiki/Hypertext_Transfer_Protocol
# /wiki/Network_News_Transfer_Protocol
# /wiki/Internet_Message_Access_Protocol
# /wiki/Secure_Shell
# /wiki/Internet_Relay_Chat
# /wiki/File_Transfer_Protocol
# /wiki/Twisted
# /wiki/GeoJSON
# /wiki/Mapping_objet-relationnel
# /wiki/SQLAlchemy
# /wiki/Syst%C3%A8me_de_gestion_de_base_de_donn%C3%A9es
# /w/index.php?title=PyGresQL&action=edit&redlink=1
# https://pypi.python.org/pypi/MySQL-python
# /wiki/Keras
# /w/index.php?title=Python_(langage)&veaction=edit&section=41
# /w/index.php?title=Python_(langage)&action=edit&section=41
# /wiki/Zen_de_Python
# /wiki/Pip_(gestionnaire_de_paquets)
# /wiki/Gestionnaire_de_paquets
# /wiki/Paquet_(logiciel)
# /wiki/Cython
# /wiki/IPython
# /wiki/RUR-PLE
# /wiki/PyPI
# /wiki/Mod%C3%A8le:Palette_Python
# https://fr.wikipedia.org/w/index.php?title=Mod%C3%A8le:Palette_Python&action=edit
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 14
#      12 soup.find_all("a")
#      13 for tag in soup.find_all("a"):
# ---> 14     print(tag["href"])
#
# File D:\Anaconda\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'href'
